# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinashvns/pandas_practice/blob/main/Pandas_Practice/pandas_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
marks=pd.Series([80,90,75,88])
print(marks)
# Out:
# 0    80
# 1    90
# 2    75
# 3    88
# dtype: int64

# %%
import pandas as pd
marks=pd.Series([80,90,75,88], index=["A", "B" ,"C","D"])
print(marks)
# Out:
# A    80
# B    90
# C    75
# D    88
# dtype: int64
